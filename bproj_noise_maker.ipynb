# %% [markdown]
# <a href="https://colab.research.google.com/github/aidaaminian/snn-self-driving/blob/main/bproj_noise_maker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Install and Import

# %%
# !gdown --id 1BuZNKbH3qWgedopUGwW9Gfue7oCbBTDm
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1BuZNKbH3qWgedopUGwW9Gfue7oCbBTDm
# To: /content/traffic-sign-yolo.zip
# 100% 261M/261M [00:05<00:00, 47.2MB/s]

# %%
# !unzip "/content/traffic-sign-yolo.zip" -d "/content/"
# Out:
# Archive:  /content/traffic-sign-yolo.zip
#    creating: /content/traffic-sign-yolo/
#   inflating: /content/traffic-sign-yolo/00000.jpg
#   inflating: /content/traffic-sign-yolo/00000.txt
#   inflating: /content/traffic-sign-yolo/00001.jpg
#   inflating: /content/traffic-sign-yolo/00001.txt
#   inflating: /content/traffic-sign-yolo/00002.jpg
#   inflating: /content/traffic-sign-yolo/00002.txt
#   inflating: /content/traffic-sign-yolo/00003.jpg
#   inflating: /content/traffic-sign-yolo/00003.txt
#   inflating: /content/traffic-sign-yolo/00004.jpg
#   inflating: /content/traffic-sign-yolo/00004.txt
#   inflating: /content/traffic-sign-yolo/00005.jpg
#   inflating: /content/traffic-sign-yolo/00005.txt
#   inflating: /content/traffic-sign-yolo/00006.jpg
#   inflating: /content/traffic-sign-yolo/00006.txt
#   inflating: /content/traffic-sign-yolo/00007.jpg
#   inflating: /content/traffic-sign-yolo/00007.txt
#   inflating: /content/traffic-sign-yolo/00008.jpg
# ...

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import skimage

# %% [markdown]
# ### Add Noise

# %%
# !mkdir ts_noise

# %%
import cv2
import glob
image_list = []
for filename in sorted(glob.glob('/content/traffic-sign-yolo/*.jpg')):
    i = int(filename[-8:-4])
    image = cv2.imread (filename)
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    image = cv2.resize(image,(240,240))

    image = np.array(image, dtype=np.float32) /255
    new_image = skimage.util.random_noise(image, mode="gaussian")
    new_image = np.array(new_image*255, dtype=np.uint8)
    cv2.imwrite("/content/ts_noise/" + "{:05d}".format(i) + ".jpg" , new_image)

# %%
# !zip -r ts-noise '/content/ts_noise/'
# Out:
#   adding: content/ts_noise/ (stored 0%)
#   adding: content/ts_noise/00193.jpg (deflated 0%)
#   adding: content/ts_noise/00463.jpg (deflated 1%)
#   adding: content/ts_noise/00838.jpg (deflated 0%)
#   adding: content/ts_noise/00038.jpg (deflated 1%)
#   adding: content/ts_noise/00251.jpg (deflated 1%)
#   adding: content/ts_noise/00369.jpg (deflated 0%)
#   adding: content/ts_noise/00307.jpg (deflated 0%)
#   adding: content/ts_noise/00072.jpg (deflated 0%)
#   adding: content/ts_noise/00828.jpg (deflated 0%)
#   adding: content/ts_noise/00603.jpg (deflated 0%)
#   adding: content/ts_noise/00316.jpg (deflated 0%)
#   adding: content/ts_noise/00401.jpg (deflated 0%)
#   adding: content/ts_noise/00236.jpg (deflated 0%)
#   adding: content/ts_noise/00160.jpg (deflated 0%)
#   adding: content/ts_noise/00656.jpg (deflated 0%)
#   adding: content/ts_noise/00216.jpg (deflated 0%)
#   adding: content/ts_noise/00672.jpg (deflated 1%)
#   adding: content/ts_noise/00608.jpg (deflated 0%)
# ...

# %% [markdown]
# ### Resize Data

# %%
# !mkdir ts_resize

# %%
import cv2
import glob
image_list = []
for filename in sorted(glob.glob('/content/traffic-sign-yolo/*.jpg')):
    i = int(filename[-8:-4])
    image = cv2.imread (filename)
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    image = cv2.resize(image,(240,240))
    cv2.imwrite("/content/ts_resize/" + "{:05d}".format(i) + ".jpg" , image)

# %%
# !zip -r ts-resize '/content/ts_resize/'
# Out:
#   adding: content/ts_resize/ (stored 0%)
#   adding: content/ts_resize/00193.jpg (deflated 1%)
#   adding: content/ts_resize/00463.jpg (deflated 1%)
#   adding: content/ts_resize/00838.jpg (deflated 1%)
#   adding: content/ts_resize/00038.jpg (deflated 1%)
#   adding: content/ts_resize/00251.jpg (deflated 1%)
#   adding: content/ts_resize/00369.jpg (deflated 1%)
#   adding: content/ts_resize/00307.jpg (deflated 2%)
#   adding: content/ts_resize/00072.jpg (deflated 1%)
#   adding: content/ts_resize/00828.jpg (deflated 1%)
#   adding: content/ts_resize/00603.jpg (deflated 1%)
#   adding: content/ts_resize/00316.jpg (deflated 1%)
#   adding: content/ts_resize/00401.jpg (deflated 1%)
#   adding: content/ts_resize/00236.jpg (deflated 1%)
#   adding: content/ts_resize/00160.jpg (deflated 1%)
#   adding: content/ts_resize/00656.jpg (deflated 1%)
#   adding: content/ts_resize/00216.jpg (deflated 2%)
#   adding: content/ts_resize/00672.jpg (deflated 1%)
# ...
